# %% [markdown]
# # Guided Project: Visualizing Earnings Based On College Majors
#
# This is a guided project from Datquest, with the objective to practice using matplotlib and pyplot, quickly creating visualisations to explore data. The data set used is based on the job outcomes of students who graduated from college between 2010 and 2012. The original aggregated data was released by American Community Survey, cleaned by FiveThirtyEight and released on their Github repository

# %%
import matplotlib.pyplot as plt 
import pandas as pd
% matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")
# returning the first row as a formatted table
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# ### Exploring the data

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape
raw_data_count
# Out:
# (173, 21)

# %%
# Removing rows that have missing values
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.shape
cleaned_data_count
# Out:
# (172, 21)

# %% [markdown]
# * Only one row had a missing value

# %% [markdown]
# ### Visualisation and exploration of data using scatter graphs
#
# The following questions will be evaluated:
#
# * Do students in more popular majors make more money?
# * Do students that majored in subjects that were majority female make more money?
# * Is there any link between the number of full-time employees and median salary?

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax1.set_title('Median vs Sample_size')
ax1.set_xlim(0,5000)
# Out:
# (0, 5000)

# %%
# Generating scatter plots
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax2.set_title('Unemployment_rate vs Sample_size')

# Setting the axis limits
ax2.set_xlim(0,5000)
ax2.set_ylim(0,0.20)
# Out:
# (0, 0.2)

# %%
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_title('Median vs Full_time')

ax3.set_xlim(0,300000)
ax3.set_ylim(0,120000)
# Out:
# (0, 120000)

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax4.set_title('Unemployment_rate vs ShareWomen')

ax4.set_xlim(0,1.2)
ax4.set_ylim(0,0.20)
# Out:
# (0, 0.2)

# %%
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax5.set_title('Median vs Men')


ax5.set_xlim(0,200000)
ax5.set_ylim(0,120000)
# Out:
# (0, 120000)

# %%
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_title('Median vs Women')

ax6.set_xlim(0,350000)
ax6.set_ylim(0,120000)
# Out:
# (0, 120000)

# %% [markdown]
# Analysis of the scatter plots:
#
# * The graphs are not appropriate to explore the questions above

# %% [markdown]
# ### Visualisation and exploration of data using histograms
#
# The following questions will be evaluated:
#
# * What percent of majors are predominantly male? Predominantly female?
# * What's the most common median salary range?

# %% [markdown]
# #### DIstribution of Sample_size

# %%
# DataFrame.hist() permits the manipulation of bins 
ax1 = recent_grads['Sample_size'].hist(bins=10, range=(0,5000))
ax1.set_xlabel("Sample_size")
ax1.set_ylabel("Frequecncy")

# %% [markdown]
# #### Distribution of Median

# %%
ax2 = recent_grads["Median"].plot(kind='hist').set_xlabel("Median")

# %% [markdown]
# * The most common median salary range is between 30000 - 40000
# * This can be validated using the value_counts() method

# %%
# DataFrame.head() method used to display the top 5 rows
recent_grads["Median"].value_counts().head()
# Out:
# 35000    20
# 40000    17
# 50000     9
# 33000     9
# 45000     9
# Name: Median, dtype: int64

# %% [markdown]
# * The most frequent median salary is 35000 followed by 40000

# %%
recent_grads["Median"].median()
# Out:
# 36000.0

# %% [markdown]
# #### Distribution of Employed

# %%
ax3 = recent_grads["Employed"].plot(kind='hist').set_xlabel("Employed")

# %% [markdown]
# #### Distribution of Full_time

# %%
ax4 = recent_grads["Full_time"].plot(kind='hist').set_xlabel("Full_time")

# %% [markdown]
# #### Distribution of ShareWomen

# %%
# Set bins = 5, to highlight when ShareWomen > 50%
ax5 = recent_grads["ShareWomen"].hist(bins=2, range=(0,1))
ax5.set_xlabel("ShareWomen")
ax5.set_ylabel("Frequency")

# %%
recent_grads["ShareWomen"].value_counts(bins=2).sort_index(ascending=False)
# Out:
# (0.484, 0.969]                     98
# (-0.0019690000000000003, 0.484]    74
# Name: ShareWomen, dtype: int64

# %% [markdown]
# * A predominant gender is determined if the gender represents greater than 50% of the total number of students
# * 98 out of 172 majors are predominantly female, meaning 57% are predominantly female and 43% are predominantly male

# %% [markdown]
# #### Distribution of Unemployment_rate

# %%
ax6 = recent_grads["Unemployment_rate"].hist(bins=5, range=(0,0.18))
ax6.set_xlabel("Unemployment_rate")
ax6.set_ylabel("Frequency")

# %% [markdown]
# #### Distribution of Men

# %%
ax7 = recent_grads["Men"].plot(kind='hist').set_xlabel("Men")

# %% [markdown]
# #### Distribution of Women

# %%
ax8 = recent_grads["Women"].plot(kind='hist').set_xlabel("Women")

# %% [markdown]
# ### Visualisation and exploration of data using a scatter matrix plot

# %%
from pandas.plotting import scatter_matrix
# Scatter_matrix while passing in a DataFrame with 2 columns returns a 2 by 2 scatter matrix plot 
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe82116b8d0>,
# ...
#       dtype=object)

# %%
#  Adjusting fig size for visibility
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe821234b70>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Women","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe820a022e8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["ShareWomen","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe82002cc88>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Full_time","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe81af609b0>,
# ...
#       dtype=object)

# %% [markdown]
# * The scatter matrix plots show that majors that are predominantly female earn less

# %%
recent_grads.head(10).plot.bar(x="Major", y="ShareWomen", legend=False).set_ylabel("ShareWomen")

# %%
recent_grads.tail(10).plot.bar(x="Major", y="ShareWomen", legend=False).set_ylabel("ShareWomen")

# %% [markdown]
# * The percentage of women taking the last 10 majors are much higher than those taking the first 10 majors, with Communication Disorders Sciences and Services, and Early Childhood Education having greater than 90% of women
# * The results show that engineering related majors have less than 40% of women

# %%
recent_grads.head(10).plot.bar(x="Major", y="Unemployment_rate", legend=False).set_ylabel("Unemployment_rate")

# %%
recent_grads.tail(10).plot.bar(x="Major", y="Unemployment_rate", legend=False).set_ylabel("Unemployment_rate")

# %% [markdown]
# * The results show that on average, the unemployment rate for the first 10 majors is less than the last 10 majors
# * However, students who took the Nuclear Engineering major have the highest unemployment rate

# %% [markdown]
# ### Additional exploration of data

# %%
# Creating new DataFrame using recent_grads data
df = pd.DataFrame(recent_grads, columns=["Major_category","Men","Women"])
df.head(10).plot.bar(x = "Major_category")

# %%
df.tail(10).plot.bar(x="Major_category")

# %% [markdown]
# *  The bar chart results verify that there are significantly less women taking engineering majors

# %%
recent_grads["Median"].plot.box(vert=False)

# %% [markdown]
# * The box plot verifies that the majority of the median salary range is between 30000 and 40000

# %%
recent_grads["Unemployment_rate"].plot.box(vert=False)

# %% [markdown]
# * The above box plot shows that the Unemployment_rate ranges from 0 to 13%

# %%
recent_grads.plot.hexbin(x="Sample_size", y="Unemployment_rate", gridsize=15)

# %% [markdown]
# * As seen from the graph above, the mean Unemployment_rate is ~6%

# %%
recent_grads.plot.hexbin(x="Full_time", y="Median", gridsize=15)

# %% [markdown]
# * As we can see from the above graph, the majority of students that were employed full time earned a median salary in the range of 30000 to 40000

# %%
recent_grads.plot.hexbin(x="Men", y="Median", gridsize=15)

# %%
recent_grads.plot.hexbin(x="Women", y="Median", gridsize=15)

# %% [markdown]
# ### Conclusion
#
# In conclusion, this project was designed to explore data by using pandas plotting tools and creating visualisations. Analysis of the data provided the following conclusions:
#
# * The graduates that were employed full-time earned an average median salary of 30000 to 40000
# * The engineering majors were predominantly occupied by men, whereas the women preferred the Psychology, Social Work, Education, Health Services and Humanities & Arts Majors
# * Majors that are predominantly occupied by women earn less
# * There's an average unemployment rate of 6%
